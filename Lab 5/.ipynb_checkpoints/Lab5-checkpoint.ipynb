# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import missingno as mn
from matplotlib.gridspec import GridSpec
from copy import deepcopy

from sklearn.metrics import classification_report, confusion_matrix, make_scorer, precision_score
from sklearn.model_selection import  cross_val_score, KFold, train_test_split, StratifiedShuffleSplit
from sklearn.preprocessing import LabelEncoder, StandardScaler, OneHotEncoder
from sklearn.pipeline import Pipeline
from sklearn.decomposition import RandomizedPCA, PCA
from sklearn.linear_model import LogisticRegression

from sklearn import metrics as mt
from keras.models import Sequential
from keras.layers import Dense, Activation, Input, Dropout
from keras.layers import Embedding, Flatten, Merge, concatenate
from keras.models import Model

import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('dataset/stats1.csv')

# %%
writer = pd.ExcelWriter('dataset/output.xlsx')
df_sub = df[:30000]

# df2 = pd.read_csv('winequality-white.csv')
# df.append(df2)
# df.rename(columns=lambda x: x.replace(' ', '_'), inplace=True)

# %%
df_participants = pd.read_csv('dataset/participants.csv')
df_part_sub = df_participants[:30000]

# %%
req_columns = ['championid', 'ss1', 'ss2', 'position', 'role']

for col in req_columns:
    df_sub[col] = df_part_sub[col]

df_sub.to_excel(writer,'Sheet1')

# %%
df_sub = pd.read_excel('dataset/output.xlsx')

# %%
df_sub.shape
# Out:
# (15000, 61)

# %%
categorical_headers = ['item1', 'item2', 'item3', 'item4', 'item5', 'item6',\
                       'trinket', 'championid', 'ss1', 'ss2', 'role', 'position']
delete_headers = ['id', 'timecc', 'win']
numeric_headers = [x for x in list(df_sub.columns) if x not in categorical_headers+delete_headers]

# %%
item_value = 0
items_combined = dict()
df_items = list()
item_headers = ['item1', 'item2', 'item3', 'item4', 'item5', 'item6']
# print(item_headers)
# df_sub.columns
for item in df_sub[item_headers].values:
#     print(item)
    my_set = frozenset(item)
    val = items_combined.get(my_set)
    if val is None:
        items_combined[my_set] = item_value
        item_value += 1
        df_items.append(item_value)
    else:
        df_items.append(val)

# %%
df_sub['items_combined'] = df_items
categorical_headers = ['items_combined', 'trinket', 'championid', 'ss1', 'ss2', 'role', 'position']
feature_columns = categorical_headers + numeric_headers

# %%
df_sub.drop(item_headers, axis=1, inplace=True)
df_sub.columns
# Out:
# Index(['id', 'win', 'trinket', 'kills', 'deaths', 'assists',
#        'largestkillingspree', 'largestmultikill', 'killingsprees',
#        'longesttimespentliving', 'doublekills', 'triplekills', 'quadrakills',
#        'pentakills', 'legendarykills', 'totdmgdealt', 'magicdmgdealt',
#        'physicaldmgdealt', 'truedmgdealt', 'largestcrit', 'totdmgtochamp',
#        'magicdmgtochamp', 'physdmgtochamp', 'truedmgtochamp', 'totheal',
#        'totunitshealed', 'dmgselfmit', 'dmgtoobj', 'dmgtoturrets',
#        'visionscore', 'timecc', 'totdmgtaken', 'magicdmgtaken', 'physdmgtaken',
#        'truedmgtaken', 'goldearned', 'goldspent', 'turretkills', 'inhibkills',
#        'totminionskilled', 'neutralminionskilled', 'ownjunglekills',
#        'enemyjunglekills', 'totcctimedealt', 'champlvl', 'pinksbought',
#        'wardsbought', 'wardsplaced', 'wardskilled', 'firstblood', 'championid',
#        'ss1', 'ss2', 'position', 'role', 'items_combined'],
#       dtype='object')

# %%
# col_list = ['admission_type_id', 'discharge_disposition_id', 'admission_source_id',
#        'payer_code', 'medical_specialty', 'number_outpatient', 'number_emergency', 
#        'number_inpatient', 'readmitted']
# for col in col_list:
#     cols.remove(col)
df = df_sub[feature_columns]
df['role'].replace('NONE', 'JUNGLE', inplace=True)
X = np.array(df)
n_samples, n_features = X.shape

# lb_make = LabelEncoder()
df_target = df_sub['win']
temp = np.array(df_target)
y_set = list(np.unique(temp))

# y = []
# for label in temp:
#     for l in y_set:
#         if l == label:
#             y.append(y_set.index(l))
            
y = np.array(temp)

n_classes = len(set(y))

print("n_samples: {}".format(n_samples))
print("n_features: {}".format(n_features))
print("n_classes: {}".format(n_classes))
# Out:
# n_samples: 15000
# n_features: 53
# n_classes: 2

# %%
df.shape
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15000 entries, 0 to 14999
# Data columns (total 53 columns):
# items_combined            15000 non-null int64
# trinket                   15000 non-null int64
# championid                15000 non-null int64
# ss1                       15000 non-null int64
# ss2                       15000 non-null int64
# role                      15000 non-null object
# position                  15000 non-null object
# kills                     15000 non-null int64
# deaths                    15000 non-null int64
# assists                   15000 non-null int64
# largestkillingspree       15000 non-null int64
# largestmultikill          15000 non-null int64
# killingsprees             15000 non-null int64
# longesttimespentliving    15000 non-null int64
# doublekills               15000 non-null int64
# triplekills               15000 non-null int64
# quadrakills               15000 non-null int64
# pentakills                15000 non-null int64
# legendarykills            15000 non-null int64
# totdmgdealt               15000 non-null int64
# magicdmgdealt             15000 non-null int64
# physicaldmgdealt          15000 non-null int64
# truedmgdealt              15000 non-null int64
# largestcrit               15000 non-null int64
# totdmgtochamp             15000 non-null int64
# magicdmgtochamp           15000 non-null int64
# physdmgtochamp            15000 non-null int64
# truedmgtochamp            15000 non-null int64
# totheal                   15000 non-null int64
# totunitshealed            15000 non-null int64
# dmgselfmit                15000 non-null int64
# dmgtoobj                  15000 non-null int64
# dmgtoturrets              15000 non-null int64
# visionscore               15000 non-null int64
# totdmgtaken               15000 non-null int64
# magicdmgtaken             15000 non-null int64
# physdmgtaken              15000 non-null int64
# truedmgtaken              15000 non-null int64
# goldearned                15000 non-null int64
# goldspent                 15000 non-null int64
# turretkills               15000 non-null int64
# inhibkills                15000 non-null int64
# totminionskilled          15000 non-null int64
# neutralminionskilled      15000 non-null int64
# ownjunglekills            15000 non-null int64
# enemyjunglekills          15000 non-null int64
# totcctimedealt            15000 non-null int64
# champlvl                  15000 non-null int64
# pinksbought               15000 non-null int64
# wardsbought               15000 non-null int64
# wardsplaced               15000 non-null int64
# wardskilled               15000 non-null int64
# firstblood                15000 non-null int64
# dtypes: int64(51), object(2)
# memory usage: 6.2+ MB

# %%
# %matplotlib inline
plt.style.use('ggplot')

#=== Fill in code below========
print('Number of instances:', n_samples)
print('Number of instances in each class:', np.bincount(y))
the_grid = GridSpec(1, 1)

plt.subplot(the_grid[0, 0], aspect=1)
plt.pie(np.bincount(y), labels=y_set, autopct='%1.1f%%', radius=2)
plt.show()
# Out:
# Number of instances: 15000
# Number of instances in each class: [7500 7500]

# %%
sss = StratifiedShuffleSplit(n_splits=10, train_size=0.8, random_state=0)

# %%
# df_values = df.values
for train_index, test_index in sss.split(df, df_target):
    df_train, df_test = df.iloc[train_index], df.iloc[test_index]
    df_target_train, df_target_test = df_target[train_index], df_target[test_index]

# %%
# categorical_headers = ['item1', 'item2', 'item3', 'item4', 'item5', 'item6', 'trinket']
# delete_headers = ['id', 'timecc', 'win']
# numeric_headers = [x for x in list(df_sub.columns) if x not in categorical_headers+delete_headers]
# feature_columns = categorical_headers + numeric_headers
# # df_test.head()

# %%
for col in numeric_headers:
    df_train[col] = df_train[col].astype(np.float)
    df_test[col] = df_test[col].astype(np.float)
    
    ss = StandardScaler()
    df_train[col] = ss.fit_transform(df_train[col].values.reshape(-1, 1))
    df_test[col] = ss.transform(df_test[col].values.reshape(-1, 1))

# %%
encoders = dict()
# print(categorical_headers)
cols = ['role', 'position']
# df.columns
for col in cols:
    df_train[col] = df_train[col].str.strip()
    df_test[col] = df_test[col].str.strip()
    encoders[col] = LabelEncoder()
    df_train[col+'_int'] = encoders[col].fit_transform(df_train[col])
    df_test[col+'_int'] = encoders[col].transform(df_test[col])

# %%
feature_columns.remove('position')
feature_columns.remove('role')
categorical_headers_ints = ['position_int', 'role_int']
feature_columns += categorical_headers_ints

# %%
X_train =  ss.fit_transform(df_train[feature_columns].values).astype(np.float32)
X_test =  ss.transform(df_test[feature_columns].values).astype(np.float32)

y_train = np.array(df_target_train)
y_test = np.array(df_target_test)
# y_train = df_train['income'].values.astype(np.int)
# y_test = df_test['income'].values.astype(np.int)

# print(X_train)

# %%
import tensorflow as tf
from tensorflow.contrib import learn
from tensorflow.contrib import layers
from tensorflow.contrib.learn.python import SKCompat
from tensorflow.contrib.learn.python.learn.estimators import model_fn as model_fn_lib
tf.logging.set_verbosity(tf.logging.WARN) # control the verbosity of tensor flow

# %%
# %%time
# we need to tell tensorflow how many inputs to expect and what the data types will be
# for this early example, everything is just numeric, real valued
features_tf = [layers.real_valued_column('', dimension=X_train.shape[1])]

clf = SKCompat(# wrap with SKCompat for easy usage like sklearn
            learn.DNNClassifier(hidden_units=[50], feature_columns=features_tf)
        )

clf.fit(X_train,y_train,steps=100)
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: C:\PROGRA~2\Java\BIN_~1\tmpgxv8fnfh
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# Wall time: 16.5 s

# %%
from sklearn import metrics as mt

yhat = clf.predict(X_test)
# notice that the output needs some interpretation
# as its not completely the same as sklearn
yhat = yhat['classes']
print(mt.confusion_matrix(y_test,yhat),
      mt.accuracy_score(y_test,yhat))
# Out:
# [[618 132]
#  [112 638]] 0.837333333333

# %%
# %%time
# we can also custimize the classifier somewhat:
clf = SKCompat(# wrap with SKCompat for easy usage like sklearn
            learn.DNNClassifier(hidden_units=[50], 
                                feature_columns=features_tf,
                                activation_fn=tf.nn.relu 
                                # tf.tanh, tf.sigmoid, tf.nn.relu, tf.nn.softmax etc.
                                )
        )

clf.fit(X_train,y_train,steps=1000)

yhat = clf.predict(X_test)['classes']
print(mt.confusion_matrix(y_test,yhat),
      mt.accuracy_score(y_test,yhat))
# Out:
# WARNING:tensorflow:Using temporary folder as model directory: C:\PROGRA~2\Java\BIN_~1\tmpbti7jtk2
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# WARNING:tensorflow:Casting <dtype: 'int64'> labels to bool.
# [[636 114]
#  [102 648]] 0.856
# Wall time: 14.6 s

# %%
pipe_lr = Pipeline([('scl', StandardScaler()),
                    ('pca', PCA(svd_solver='randomized',n_components=20,random_state=1)),
                    ('clf', LogisticRegression(class_weight='balanced', random_state=1))])

pipe_lr.fit(X_train, y_train)
y_pred = pipe_lr.predict(X_test)
print(classification_report(y_test, y_pred))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.79      0.86      0.82       750
#           1       0.85      0.77      0.81       750
#
# avg / total       0.82      0.82      0.82      1500

# %%
import numpy as np



from sklearn.model_selection import StratifiedKFold
kfold = StratifiedKFold(n_splits=10,
                            random_state=1).split(X_train, y_train)
    
scores = []
for k, (train, test) in enumerate(kfold):
    pipe_lr.fit(X_train[train], y_train[train])
    score = pipe_lr.score(X_train[test], y_train[test])
    scores.append(score)
    print('Fold: %s, Acc: %.3f' % (k+1, score))
    
print('\nCV accuracy: %.3f +/- %.3f' % (np.mean(scores), np.std(scores)))
# Out:
# Fold: 1, Acc: 0.820
# Fold: 2, Acc: 0.798
# Fold: 3, Acc: 0.834
# Fold: 4, Acc: 0.818
# Fold: 5, Acc: 0.816
# Fold: 6, Acc: 0.818
# Fold: 7, Acc: 0.823
# Fold: 8, Acc: 0.814
# Fold: 9, Acc: 0.843
# Fold: 10, Acc: 0.829
#
# CV accuracy: 0.821 +/- 0.011

# %%
# combine the features with two branches

# let's encode the integer outputs as one hot encoded labels
ohe = OneHotEncoder()
X_train_ohe = ohe.fit_transform(df_train[categorical_headers_ints].values)
X_test_ohe = ohe.transform(df_test[categorical_headers_ints].values)

# and save off the numeric features
X_train_num =  df_train[numeric_headers].values
X_test_num = df_test[numeric_headers].values

# create sparse input branch for ohe
inputsSparse = Input(shape=(X_train_ohe.shape[1],),sparse=True, name='X_ohe')
xSparse = Dense(units=10, activation='relu', name='ohe_1')(inputsSparse)

# create dense input branch for numeric
inputsDense = Input(shape=(X_train_num.shape[1],),sparse=False, name='X_Numeric')
xDense = Dense(units=10, activation='relu',name='num_1')(inputsDense)

x = concatenate([xSparse, xDense], name='concat')
predictions = Dense(1,activation='sigmoid', name='combined')(x)

# This creates a model that includes
# the Input layer and Dense layers
model = Model(inputs=[inputsSparse,inputsDense], outputs=predictions)

model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# X_ohe (InputLayer)              (None, 9)            0
# __________________________________________________________________________________________________
# X_Numeric (InputLayer)          (None, 46)           0
# __________________________________________________________________________________________________
# ohe_1 (Dense)                   (None, 10)           100         X_ohe[0][0]
# __________________________________________________________________________________________________
# num_1 (Dense)                   (None, 10)           470         X_Numeric[0][0]
# __________________________________________________________________________________________________
# concat (Concatenate)            (None, 20)           0           ohe_1[0][0]
#                                                                  num_1[0][0]
# __________________________________________________________________________________________________
# combined (Dense)                (None, 1)            21          concat[0][0]
# ==================================================================================================
# Total params: 591
# Trainable params: 591
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
# we need to create separate sequential models for each embedding
embed_branches = []
X_ints_train = []
X_ints_test = []
all_inputs = []
all_branch_outputs = []
categorical_headers_ints = ['position_int', 'role_int']

for col in categorical_headers_ints:
    # encode as ints for the embedding
    X_ints_train.append( df_train[col].values )
    X_ints_test.append( df_test[col].values )
    
    # get the number of categories
    N = max(X_ints_train[-1]+1) # same as the max(df_train[col])
    
    # create embedding branch from the number of categories
    inputs = Input(shape=(1,),dtype='int32', name=col)
    all_inputs.append( inputs )
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(inputs)
    x = Flatten()(x)
    all_branch_outputs.append(x)

# also get a dense branch of the numeric features
all_inputs.append(Input(shape=(X_train_num.shape[1],),sparse=False, name='numeric'))
x = Dense(units=20, activation='relu',name='numeric_1')(all_inputs[-1])
all_branch_outputs.append( Dense(units=10,activation='relu', name='numeric_2')(x) )

# merge the branches together
final_branch = concatenate(all_branch_outputs, name='concat_1')
final_branch = Dense(units=1,activation='sigmoid', name='combined')(final_branch)

model = Model(inputs=all_inputs, outputs=final_branch)

# %%
df_train.head()
# Out:
#       items_combined  trinket  championid  ss1  ss2         role position  \
# 9938            9216     3340          75    4   12         SOLO      TOP
# 2622            2492     3364          25    3    4  DUO_SUPPORT      BOT
# 977              958     3340         105    4   11       JUNGLE   JUNGLE
# 1756            1690     3364         143    4    3  DUO_SUPPORT      BOT
# 5375            4987     3340           5    4   11       JUNGLE   JUNGLE
#
#          kills    deaths   assists      ...       enemyjunglekills  \
# 9938 -0.936696 -0.763802 -0.827521      ...               0.105242
# 2622 -0.735469 -0.763802  0.140183      ...              -0.539378
# 977   0.471895  0.088101 -1.472657      ...               1.118216
# 1756 -0.131787 -0.479834  0.140183      ...              -0.263112
# 5375 -0.735469  0.088101 -0.666237      ...               3.420431
#
#       totcctimedealt  champlvl  pinksbought  wardsbought  wardsplaced  \
# 9938        0.135570  0.784099    -0.595646     -0.17185    -0.461510
# 2622       -0.087126  0.035079     0.372359     -0.17185     1.525411
# 977         0.215209 -0.339431    -0.595646     -0.17185    -0.461510
# 1756       -0.227232  0.035079     0.372359     -0.17185     0.673873
# 5375        0.210785  0.035079    -0.595646     -0.17185     0.248105
#
#       wardskilled  firstblood  role_int  position_int
# 9938    -0.610796    -0.33287         4             3
# 2622     1.532974    -0.33287         2             0
# 977     -0.610796    -0.33287         3             1
# 1756     0.675466    -0.33287         2             0
# 5375    -0.182042    -0.33287         3             1
#
# [5 rows x 55 columns]

# %%
cross_columns = [['kills', 'deaths', 'assists'],
                 ['championid', 'champlvl' ]]

# we need to create separate sequential models for each embedding
embed_branches = []
X_ints_train = []
X_ints_test = []
all_inputs = []
all_branch_outputs = []

for cols in cross_columns:
    # encode as ints for the embedding
    enc = LabelEncoder()
    
#     # 1. create crossed labels by join operation
    X_crossed_train = df_train[cols].apply(lambda x: '_'.join(str(x)), axis=1)
    X_crossed_test = df_test[cols].apply(lambda x: '_'.join(str(x)), axis=1)
    
    # 2. encode as integers
    enc.fit(np.hstack((X_crossed_train.values,  X_crossed_test.values)))
    X_crossed_train = enc.transform(X_crossed_train)
    X_crossed_test = enc.transform(X_crossed_test)
    
    # 3. save encodings in a list for each branch
    X_ints_train.append( X_crossed_train )
    X_ints_test.append( X_crossed_test )
    
    # get the number of categories in the crossing
    N = max(X_ints_train[-1]+1) # same as the max(df_train[col])
    
    # create embedding branch from the crossed encoding
    inputs = Input(shape=(1,),dtype='int32',name='_'.join(cols))
    all_inputs.append(inputs)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name='_'.join(cols)+'_embed')(inputs)
    x = Flatten()(x)
    all_branch_outputs.append(x)
    
# merge the branches together
final_branch = concatenate(all_branch_outputs)
# add a layer after merging
final_branch = Dense(units=1,activation='sigmoid',name='combined')(final_branch)

model = Model(inputs=all_inputs, outputs=final_branch)

# %%
# from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot
# SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
embed_branches = []
X_ints_train = []
X_ints_test = []
all_inputs = []
all_branch_outputs = []

for cols in cross_columns:
    # encode crossed columns as ints for the embedding
    enc = LabelEncoder()
    
    # create crossed labels
    # needs to be commented better, Eric!
    X_crossed_train = df_train[cols].apply(lambda x: '_'.join(str(x)), axis=1)
    X_crossed_test = df_test[cols].apply(lambda x: '_'.join(str(x)), axis=1)
    
    enc.fit(np.hstack((X_crossed_train.values,  X_crossed_test.values)))
    X_crossed_train = enc.transform(X_crossed_train)
    X_crossed_test = enc.transform(X_crossed_test)
    X_ints_train.append( X_crossed_train )
    X_ints_test.append( X_crossed_test )
    
    # get the number of categories
    N = max(X_ints_train[-1]+1) # same as the max(df_train[col])
    
    # create embedding branch from the number of categories
    inputs = Input(shape=(1,),dtype='int32', name = '_'.join(cols))
    all_inputs.append(inputs)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name = '_'.join(cols)+'_embed')(inputs)
    x = Flatten()(x)
    all_branch_outputs.append(x)
    
# merge the branches together
wide_branch = concatenate(all_branch_outputs, name='wide_concat')

# reset this input branch
all_branch_outputs = []
# add in the embeddings
for col in categorical_headers_ints:
    # encode as ints for the embedding
    X_ints_train.append( df_train[col].values )
    X_ints_test.append( df_test[col].values )
    
    # get the number of categories
    N = max(X_ints_train[-1]+1) # same as the max(df_train[col])
    
    # create embedding branch from the number of categories
    inputs = Input(shape=(1,),dtype='int32', name=col)
    all_inputs.append(inputs)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(inputs)
    x = Flatten()(x)
    all_branch_outputs.append(x)
    
# also get a dense branch of the numeric features
all_inputs.append(Input(shape=(X_train_num.shape[1],),
                        sparse=False,
                        name='numeric_data'))

x = Dense(units=20, activation='relu',name='numeric_1')(all_inputs[-1])
all_branch_outputs.append( x )

# merge the branches together
deep_branch = concatenate(all_branch_outputs,name='concat_embeds')
deep_branch = Dense(units=50,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=25,activation='relu', name='deep2')(deep_branch)
deep_branch = Dense(units=10,activation='relu', name='deep3')(deep_branch)
    
final_branch = concatenate([wide_branch, deep_branch],name='concat_deep_wide')
final_branch = Dense(units=1,activation='sigmoid',name='combined')(final_branch)

model = Model(inputs=all_inputs, outputs=final_branch)

# %%
# from IPython.display import SVG
# from keras.utils.vis_utils import model_to_dot

# # you will need to install pydot properly on your machine to get this running
# SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
# %%time

model.compile(optimizer='adagrad',
              loss='mean_squared_error',
              metrics=['accuracy'])
# lets also add the history variable to see how we are doing
history = model.fit(X_ints_train+ [X_train_num],
                    y_train, 
                    epochs=10, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = (X_ints_test + [X_test_num], y_test))
# Out:
# Train on 12000 samples, validate on 1500 samples
# Epoch 1/10
# 12000/12000 [==============================] - 24s 2ms/step - loss: 0.1347 - acc: 0.8077 - val_loss: 0.1151 - val_acc: 0.8353
# Epoch 2/10
# 12000/12000 [==============================] - 24s 2ms/step - loss: 0.0821 - acc: 0.8934 - val_loss: 0.1179 - val_acc: 0.8467
# Epoch 3/10
# 12000/12000 [==============================] - 24s 2ms/step - loss: 0.0320 - acc: 0.9832 - val_loss: 0.1262 - val_acc: 0.8473
# Epoch 4/10
# 12000/12000 [==============================] - 25s 2ms/step - loss: 0.0091 - acc: 0.9997 - val_loss: 0.1302 - val_acc: 0.8413
# Epoch 5/10
# 12000/12000 [==============================] - 25s 2ms/step - loss: 0.0042 - acc: 0.9999 - val_loss: 0.1301 - val_acc: 0.8427
# Epoch 6/10
# 12000/12000 [==============================] - 23s 2ms/step - loss: 0.0026 - acc: 0.9999 - val_loss: 0.1300 - val_acc: 0.8427
# Epoch 7/10
# 12000/12000 [==============================] - 24s 2ms/step - loss: 0.0018 - acc: 1.0000 - val_loss: 0.1299 - val_acc: 0.8433
# Epoch 8/10
# 12000/12000 [==============================] - 24s 2ms/step - loss: 0.0014 - acc: 1.0000 - val_loss: 0.1298 - val_acc: 0.8427
# Epoch 9/10
# 12000/12000 [==============================] - 24s 2ms/step - loss: 0.0011 - acc: 1.0000 - val_loss: 0.1296 - val_acc: 0.8427
# Epoch 10/10
# 12000/12000 [==============================] - 25s 2ms/step - loss: 9.1203e-04 - acc: 1.0000 - val_loss: 0.1295 - val_acc: 0.8413
# Wall time: 4min 2s

# %%
cross_columns = [['kills', 'deaths', 'assists', 'totdmgtochamp', 'items_combined'],
                 ['championid'],
                 ['doublekills', 'triplekills', 'quadrakills', 'pentakills']]

embed_branches = []
X_ints_train = []
X_ints_test = []
all_inputs = []
all_branch_outputs = []

for cols in cross_columns:
    # encode crossed columns as ints for the embedding
    enc = LabelEncoder()
    
    # create crossed labels
    # needs to be commented better, Eric!
    X_crossed_train = df_train[cols].apply(lambda x: '_'.join(str(x)), axis=1)
    X_crossed_test = df_test[cols].apply(lambda x: '_'.join(str(x)), axis=1)
    
    enc.fit(np.hstack((X_crossed_train.values,  X_crossed_test.values)))
    X_crossed_train = enc.transform(X_crossed_train)
    X_crossed_test = enc.transform(X_crossed_test)
    X_ints_train.append( X_crossed_train )
    X_ints_test.append( X_crossed_test )
    
    # get the number of categories
    N = max(X_ints_train[-1]+1) # same as the max(df_train[col])
    
    # create embedding branch from the number of categories
    inputs = Input(shape=(1,),dtype='int32', name = '_'.join(cols))
    all_inputs.append(inputs)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name = '_'.join(cols)+'_embed')(inputs)
    x = Flatten()(x)
    all_branch_outputs.append(x)
    
# merge the branches together
wide_branch = concatenate(all_branch_outputs, name='wide_concat')

# reset this input branch
all_branch_outputs = []
# add in the embeddings
for col in categorical_headers_ints:
    # encode as ints for the embedding
    X_ints_train.append( df_train[col].values )
    X_ints_test.append( df_test[col].values )
    
    # get the number of categories
    N = max(X_ints_train[-1]+1) # same as the max(df_train[col])
    
    # create embedding branch from the number of categories
    inputs = Input(shape=(1,),dtype='int32', name=col)
    all_inputs.append(inputs)
    x = Embedding(input_dim=N, 
                  output_dim=int(np.sqrt(N)), 
                  input_length=1, name=col+'_embed')(inputs)
    x = Flatten()(x)
    all_branch_outputs.append(x)
    
# also get a dense branch of the numeric features
all_inputs.append(Input(shape=(X_train_num.shape[1],),
                        sparse=False,
                        name='numeric_data'))

x = Dense(units=20, activation='relu',name='numeric_1')(all_inputs[-1])
all_branch_outputs.append( x )


# merge the branches together
deep_branch = concatenate(all_branch_outputs,name='concat_embeds')
model1 = Model(inputs=all_inputs, outputs=x)
deep_branch = Dense(units=100,activation='relu', name='deep1')(deep_branch)
deep_branch = Dense(units=50,activation='relu', name='deep2')(deep_branch)
deep_branch = Dense(units=25,activation='relu', name='deep3')(deep_branch)
deep_branch = Dropout(0.5)(deep_branch)
deep_branch = Dense(units=10,activation='relu', name='deep4')(deep_branch)
    
final_branch = concatenate([wide_branch, deep_branch],name='concat_deep_wide')
final_branch = Dense(units=1,activation='sigmoid',name='combined')(final_branch)

model = Model(inputs=all_inputs, outputs=final_branch)

# %%
from IPython.display import SVG
from keras.utils.vis_utils import model_to_dot
# import pydot
 
# you will need to install pydot properly on your machine to get this running
SVG(model_to_dot(model).create(prog='dot', format='svg'))

# %%
# %%time

model.compile(optimizer='adagrad',
              loss='mean_squared_error',
              metrics=['accuracy'])
# lets also add the history variable to see how we are doing
history = model.fit(X_ints_train+ [X_train_num],
                    y_train, 
                    epochs=10, 
                    batch_size=32, 
                    verbose=1, 
                    validation_data = (X_ints_test + [X_test_num], y_test))
# Out:
# Train on 12000 samples, validate on 1500 samples
# Epoch 1/10
# 12000/12000 [==============================] - 33s 3ms/step - loss: 0.1411 - acc: 0.8037 - val_loss: 0.1200 - val_acc: 0.8347
# Epoch 2/10
# 12000/12000 [==============================] - 31s 3ms/step - loss: 0.0768 - acc: 0.9142 - val_loss: 0.1270 - val_acc: 0.8287
# Epoch 3/10
# 12000/12000 [==============================] - 31s 3ms/step - loss: 0.0190 - acc: 0.9954 - val_loss: 0.1392 - val_acc: 0.8260
# Epoch 4/10
# 12000/12000 [==============================] - 32s 3ms/step - loss: 0.0051 - acc: 0.9996 - val_loss: 0.1417 - val_acc: 0.8260
# Epoch 5/10
# 12000/12000 [==============================] - 32s 3ms/step - loss: 0.0026 - acc: 0.9999 - val_loss: 0.1423 - val_acc: 0.8260
# Epoch 6/10
# 12000/12000 [==============================] - 32s 3ms/step - loss: 0.0017 - acc: 1.0000 - val_loss: 0.1416 - val_acc: 0.8253
# Epoch 7/10
# 12000/12000 [==============================] - 31s 3ms/step - loss: 0.0012 - acc: 1.0000 - val_loss: 0.1416 - val_acc: 0.8247
# Epoch 8/10
# 12000/12000 [==============================] - 32s 3ms/step - loss: 0.0010 - acc: 0.9999 - val_loss: 0.1420 - val_acc: 0.8267
# Epoch 9/10
# 12000/12000 [==============================] - 32s 3ms/step - loss: 7.7514e-04 - acc: 1.0000 - val_loss: 0.1417 - val_acc: 0.8267
# Epoch 10/10
# 12000/12000 [==============================] - 32s 3ms/step - loss: 6.6945e-04 - acc: 1.0000 - val_loss: 0.1422 - val_acc: 0.8253
# Wall time: 5min 20s

# %%
from matplotlib import pyplot as plt

# %matplotlib inline

plt.figure(figsize=(10,4))
plt.subplot(2,2,1)
plt.plot(history.history['acc'])
plt.ylabel('Accuracy %')
plt.title('Training')
plt.subplot(2,2,2)
plt.plot(history.history['val_acc'])
plt.title('Validation')

plt.subplot(2,2,3)
plt.plot(history.history['loss'])
plt.ylabel('MSE Training Loss')
plt.xlabel('epochs')

plt.subplot(2,2,4)
plt.plot(history.history['val_loss'])
plt.xlabel('epochs')
# Out:
# Text(0.5,0,'epochs')

# %%
model1.compile(optimizer='adagrad',
              loss='mean_squared_error',
              metrics=['accuracy'])

history = model1.fit(X_ints_train+ [X_train_num],
                    y_train, 
                    epochs=10, 
                    batch_size=32, 
                    verbose=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-8b8151395cbc> in <module>()
#       7                     epochs=10,
#       8                     batch_size=32,
# ----> 9                     verbose=1)
#      10
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1628             sample_weight=sample_weight,
#    1629             class_weight=class_weight,
# -> 1630             batch_size=batch_size)
#    1631         # Prepare validation data.
#    1632         do_validation = False
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, check_array_lengths, batch_size)
#    1478                                     output_shapes,
#    1479                                     check_batch_axis=False,
# -> 1480                                     exception_prefix='target')
#    1481         sample_weights = _standardize_sample_weights(sample_weight,
#    1482                                                      self._feed_output_names)
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in _standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     121                             ': expected ' + names[i] + ' to have shape ' +
#     122                             str(shape) + ' but got array with shape ' +
# --> 123                             str(data_shape))
#     124     return data
#     125
#
# ValueError: Error when checking target: expected numeric_1 to have shape (20,) but got array with shape (1,)

# %%
for layer in model.layers:
#     print(type(layer))
#     print(layer.get_config()['name'])
    if layer.get_config()['name'] == 'doublekills_triplekills_quadrakills_pentakills_embed':
        h = layer.get_weights()
        o = layer.get_output_shape_at(0)

# print (np.array(h)[0][:12000].shape)
# print (h[0])
# print (X_train_num.shape)
# print (X_train_num)
# print (np.array(y_train).shape)
print (o)
# Out:
# (None, 1, 116)

# %%
from time import time
from sklearn.manifold import TSNE
from matplotlib.ticker import NullFormatter

X_tsne = X_ints_train+ [X_train_num]
# print(X_train_num)

t0 = time()
tsne = TSNE(n_components=2, init='random', random_state=0)
Y = tsne.fit_transform(h[0][:1000])
t1 = time()

# %%
fig = plt.figure(figsize=(15, 8))
print("t-SNE: %.2g sec" % (t1 - t0))
ax = fig.add_subplot(111)
plt.scatter(Y[:, 0], Y[:, 1], c=y_train[:1000], cmap=plt.cm.get_cmap('RdYlGn'))
plt.title("t-SNE (%.2g sec)" % (t1 - t0))
ax.xaxis.set_major_formatter(NullFormatter())
ax.yaxis.set_major_formatter(NullFormatter())
plt.axis('tight')

plt.show()
# Out:
# t-SNE: 48 sec

# %%
X_ints_train+ [X_train_num]
