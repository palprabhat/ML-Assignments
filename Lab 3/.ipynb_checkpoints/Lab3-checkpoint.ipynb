# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")

df = pd.read_csv('dataset/timesData.csv')

df.head()
# Out:
#   world_rank                        university_name                   country  \
# 0          1                     Harvard University  United States of America
# 1          2     California Institute of Technology  United States of America
# 2          3  Massachusetts Institute of Technology  United States of America
# 3          4                    Stanford University  United States of America
# 4          5                   Princeton University  United States of America
#
#    teaching  international  research  citations  income  total_score  \
# 0      99.7           72.4      98.7       98.8    34.5         96.1
# 1      97.7           54.6      98.0       99.9    83.7         96.0
# 2      97.8           82.3      91.4       99.9    87.5         95.6
# 3      98.3           29.5      98.1       99.2    64.3         94.3
# 4      90.9           70.3      95.4       99.9     0.0         94.2
#
#   num_students  student_staff_ratio  international_students female_male_ratio  \
# 0       20,152                  8.9                    25.0               NaN
# 1        2,243                  6.9                    27.0           33 : 67
# 2       11,074                  9.0                    33.0           37 : 63
# 3       15,596                  7.8                    22.0           42 : 58
# 4        7,929                  8.4                    27.0           45 : 55
#
#    year
# 0  2011
# 1  2011
# 2  2011
# 3  2011
# 4  2011

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2603 entries, 0 to 2602
# Data columns (total 14 columns):
# world_rank                2603 non-null object
# university_name           2603 non-null object
# country                   2603 non-null object
# teaching                  2603 non-null float64
# international             2603 non-null float64
# research                  2603 non-null float64
# citations                 2603 non-null float64
# income                    2603 non-null float64
# total_score               2603 non-null float64
# num_students              2544 non-null object
# student_staff_ratio       2544 non-null float64
# international_students    2536 non-null float64
# female_male_ratio         2370 non-null object
# year                      2603 non-null int64
# dtypes: float64(8), int64(1), object(5)
# memory usage: 284.8+ KB

# %%
import missingno as mn
mn.matrix(df)

# %%
df.isnull().any()
# Out:
# world_rank                False
# university_name           False
# country                   False
# teaching                  False
# international             False
# research                  False
# citations                 False
# income                    False
# total_score               False
# num_students               True
# student_staff_ratio        True
# international_students     True
# female_male_ratio          True
# year                      False
# dtype: bool

# %%
df['num_students'] = df['num_students'].fillna(value=0)
df['international_students'] = df['international_students'].str.replace("%","").astype(float)
df['international_students'] = df['international_students'].fillna(value=0)
df['international_students'] = df['international_students']/100
df['student_staff_ratio'] = df['student_staff_ratio'].fillna(value=0)
df['female_male_ratio'] = df['student_staff_ratio'].fillna(value=0)
df['num_students'] = df['num_students'].str.replace(",","")
df['num_students'] = df['num_students'].astype(float)

to_replace = ['student_staff_ratio', 'num_students', 'international_students']

for i in to_replace:
    df[i] = df[i].replace(np.NaN, 0)
mn.matrix(df)

# %%
from sklearn.preprocessing import LabelEncoder
lb_make = LabelEncoder()

labels = ['country']
for label in labels:
    df[label+'_code'] = lb_make.fit_transform(df[label])

# %%
cols = list(df.columns)
cols.remove('total_score')
cols.remove('world_rank')
cols.remove('university_name')
cols.remove('country')

X = df[cols]
X = np.array(X)

y = df['total_score']
y = np.array(y)
y = y.astype(int)

# %%
from sklearn.model_selection import ShuffleSplit, train_test_split
from sklearn import svm
from sklearn import metrics as mt
from sklearn.metrics import accuracy_score
from scipy.special import expit

# %%
# %%time

for i in range(5):
    
    print("\n====Iteration",i," ====")
    for kernel in ['sigmoid', 'rbf']:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
        y_hat = svm.SVC(kernel=kernel, gamma=0.015).fit(X_train,y_train).predict(X_test) # get test set precitions
        acc = mt.accuracy_score(y_test,y_hat)
        print("accuracy:", acc*100, "%", "with kernel =", kernel)
# Out:
# ====Iteration 0  ====
# accuracy: 51.8234165067 % with kernel = sigmoid
# accuracy: 54.3186180422 % with kernel = rbf
#
# ====Iteration 1  ====
# accuracy: 54.5105566219 % with kernel = sigmoid
# accuracy: 53.1669865643 % with kernel = rbf
#
# ====Iteration 2  ====
# accuracy: 55.2783109405 % with kernel = sigmoid
# accuracy: 55.0863723608 % with kernel = rbf
#
# ====Iteration 3  ====
# accuracy: 57.0057581574 % with kernel = sigmoid
# accuracy: 58.1573896353 % with kernel = rbf
#
# ====Iteration 4  ====
# accuracy: 55.4702495202 % with kernel = sigmoid
# accuracy: 51.8234165067 % with kernel = rbf
# Wall time: 51.1 s

# %%
# from last time, our logistic regression algorithm is given by (including everything we previously had):
class BinaryLogisticRegression:
    def __init__(self, eta, iterations=20, C=0.001, norm='L2'):
        self.eta = eta
        self.iters = iterations
        self.C = C
        self.norm = norm
        # internally we will store the weights as self.w_ to keep with sklearn conventions
        
    def __str__(self):
        if(hasattr(self,'w_')):
            return 'Binary Logistic Regression Object with coefficients:\n'+ str(self.w_) # is we have trained the object
        else:
            return 'Untrained Binary Logistic Regression Object'
        
    # convenience, private:
    @staticmethod
    def _add_bias(X):
        return np.hstack((np.ones((X.shape[0],1)),X)) # add bias term
    
    @staticmethod
    def _sigmoid(theta):
        # increase stability, redefine sigmoid operation
        return expit(theta) #1/(1+np.exp(-theta))
    
    # vectorized gradient calculation
    def _get_gradient(self,X,y):
        ydiff = y-self.predict_proba(X,add_bias=False).ravel() # get y difference
        gradient = np.mean(X * ydiff[:,np.newaxis], axis=0) # make ydiff a column vector and multiply through
        
        gradient = gradient.reshape(self.w_.shape)
#         gradient[1:] += -2 * self.w_[1:] * self.C
        return gradient
    
    # public:
    def predict_proba(self,X,add_bias=True):
        # add bias term if requested
        Xb = self._add_bias(X) if add_bias else X
        return self._sigmoid(Xb @ self.w_) # return the probability y=1
    
    def predict(self,X):
        return (self.predict_proba(X)>0.5) #return the actual prediction
    
    
    def fit(self, X, y):
        Xb = self._add_bias(X) # add bias term
        num_samples, num_features = Xb.shape
        
        self.w_ = np.zeros((num_features,1)) # init weight vector to zeros
        
        # for as many as the max iterations
        for _ in range(self.iters):
            gradient = self._get_gradient(Xb,y)
            self.w_ += gradient*self.eta # multiply by learning rate

# %%
class SteepestLogisticRegression(BinaryLogisticRegression):
    
    def _get_gradient(self, X, y):
        gradient = 0
        for i, j in zip(X, y):
            ydiff = j - self.predict_proba(i, add_bias=False)
            gradient += i * ydiff[:,np.newaxis]
        
        gradient = gradient.reshape(self.w_.shape)
#         gradient[1:] += -2 * self.w_[1:] * self.C
        
        if self.norm.lower() == 'l1':
            gradient[1:] += np.abs(self.w_[1:])/self.w_[1:] * self.C
        elif self.norm.lower() == 'l2':
            gradient[1:] += -2 * self.w_[1:] * self.C
        elif self.norm.lower() == 'both':
            gradient[1:] += (np.abs(self.w_[1:])/self.w_[1:] * self.C) + (-2 * self.w_[1:] * self.C)
        
        return gradient

# %%
class StochasticLogisticRegression(BinaryLogisticRegression):
    # stochastic gradient calculation 
    def _get_gradient(self,X,y):
        idx = int(np.random.rand()*len(y)) # grab random instance
        ydiff = y[idx]-self.predict_proba(X[idx],add_bias=False) # get y difference (now scalar)
        gradient = X[idx] * ydiff[:,np.newaxis] # make ydiff a column vector and multiply through
        
        gradient = gradient.reshape(self.w_.shape)
        
        if self.norm.lower() == 'l1':
            gradient[1:] += np.abs(self.w_[1:])/self.w_[1:] * self.C
        elif self.norm.lower() == 'l2':
            gradient[1:] += -2 * self.w_[1:] * self.C
        elif self.norm.lower() == 'both':
            gradient[1:] += (np.abs(self.w_[1:])/self.w_[1:] * self.C) + (-2 * self.w_[1:] * self.C)
        
        return gradient

# %%
from scipy.optimize import fmin_bfgs
class BFGSMulticlassLogisticRegression(BinaryLogisticRegression):
    
    @staticmethod
    def objective_function(w,X,y,C):
        g = expit(X @ w)
        return -np.sum(np.log(g[y==1]))-np.sum(np.log(1-g[y==0])) + C*sum(w**2) #-np.sum(y*np.log(g)+(1-y)*np.log(1-g))

#     @staticmethod
    def objective_gradient(self,w,X,y,C):
        g = expit(X @ w)
        ydiff = y-g # get y difference
        gradient = np.mean(X * ydiff[:,np.newaxis], axis=0)
        gradient = gradient.reshape(w.shape)
#         gradient[1:] += -2 * w[1:] * C
        if self.norm.lower() == 'l1':
            gradient[1:] += np.abs(w[1:])/w[1:] * C
        elif self.norm.lower() == 'l2':
            gradient[1:] += -2 * w[1:] * C
        elif self.norm.lower() == 'both':
            gradient[1:] += (np.abs(w[1:])/w[1:] * C) + (-2 * w[1:] * C)
        return -gradient
    
    # just overwrite fit function
    def fit(self, X, y):
        Xb = self._add_bias(X) # add bias term
        num_samples, num_features = Xb.shape
        
        self.w_ = fmin_bfgs(self.objective_function, # what to optimize
                            np.zeros((num_features,1)), # starting point
                            fprime=self.objective_gradient, # gradient function
                            args=(Xb,y,self.C), # extra args for gradient and objective function
                            gtol=1e-03, # stopping criteria for gradient, |v_k|
                            maxiter=self.iters, # stopping criteria iterations
                            disp=False)
        
        self.w_ = self.w_.reshape((num_features,1))

# %%
class MultiClassLogisticRegression:
    def __init__(self, eta, iterations=20, C=0.0001,  optimized_tech='binary', norm='L2'):
        self.eta = eta
        self.iters = iterations
        self.C = C
        self.classifiers_ = []
        self.optimized_tech = optimized_tech
        self.norm = norm
        # internally we will store the weights as self.w_ to keep with sklearn conventions
    
    def __str__(self):
        if(hasattr(self,'w_')):
            return 'MultiClass Logistic Regression Object with coefficients:\n'+ str(self.w_) # is we have trained the object
        else:
            return 'Untrained MultiClass Logistic Regression Object'
        
    def fit(self,X,y):
        num_samples, num_features = X.shape
        self.unique_ = np.sort(np.unique(y)) # get each unique class value

        num_unique_classes = len(self.unique_)
        self.classifiers_ = []
        for i,yval in enumerate(self.unique_): # for each unique value
            y_binary = y==yval # create a binary problem
            
            # train the binary classifier for this class
            blr = None
            if(self.optimized_tech.lower() == 'steepest'):
                blr = SteepestLogisticRegression(self.eta,self.iters,self.C,self.norm)
            elif(self.optimized_tech.lower() == 'stochastic'):
                blr = StochasticLogisticRegression(self.eta,self.iters,self.C,self.norm)
            elif(self.optimized_tech.lower() == 'bfgs'):
                blr = BFGSMulticlassLogisticRegression(self.eta,self.iters,self.C,self.norm)
            elif(self.optimized_tech.lower() == 'binary'):
                blr = BinaryLogisticRegression(self.eta,self.iters,self.C,self.norm)
            elif(self.optimized_tech.lower() == 'mse'):
                blr = MSELogisticRegression(self.eta,self.iters,self.C,self.norm)
            blr.fit(X,y_binary)

            # print(accuracy_score(y_binary,blr.predict(X)))
            # add the trained classifier to the list
            self.classifiers_.append(blr)
            
        # save all the weights into one matrix, separate column for each class
        self.w_ = np.hstack([x.w_ for x in self.classifiers_]).T
        
    def predict_proba(self,X):
        probs = []
        for blr in self.classifiers_:
            probs.append(blr.predict_proba(X).reshape((len(X),1))) # get probability for each classifier
        
        return np.hstack(probs) # make into single matrix
    
    def predict(self,X):
        return np.argmax(self.predict_proba(X),axis=1) # take argmax along row

# %%
# %%time
mlr = MultiClassLogisticRegression(eta=0.01,iterations=3,C=0.001,optimized_tech='bfgs')
C_val = [0.001, 0.01, 0.1, 1, 10]

for i in range(2): 
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    print("\n====Iteration",i," ====")
    
    mlr.fit(X_train,y_train)

    yhat = mlr.predict(X_test)
    print('Accuracy of test: ',accuracy_score(y_test,yhat)*100)
    
    yhat_train = mlr.predict(X_train)
    print('Accuracy of train: ',accuracy_score(y_train,yhat_train)*100)
# Out:
# ====Iteration 0  ====
# Accuracy of test:  57.773512476
# Accuracy of train:  52.5936599424
#
# ====Iteration 1  ====
# Accuracy of test:  53.9347408829
# Accuracy of train:  53.7944284342
# Wall time: 2.24 s

# %%
opt = ['steepest', 'stochastic', 'bfgs']
iteration = [100, 1000, 3]
C_val = [0.001, 0.01, 0.1, 1, 10]

acc_set = []
for o,i in zip(opt, iteration):
    print("\nOptimization:", o)
    accuracy = []
    
    for j in C_val:
        mlr = MultiClassLogisticRegression(eta=0.01,iterations=i,C=j,optimized_tech=o,norm='l2')
        
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)    
        mlr.fit(X_train,y_train)
        yhat = mlr.predict(X_test)
        acc = accuracy_score(y_test,yhat) * 100
        print('C=', j, 'gives an accuracy of: ', acc, '%')
        accuracy.append(acc)
    acc_set.append(accuracy)
# Out:
# Optimization: steepest
# C= 0.001 gives an accuracy of:  51.8234165067 %
# C= 0.01 gives an accuracy of:  1.15163147793 %
# C= 0.1 gives an accuracy of:  51.6314779271 %
# C= 1 gives an accuracy of:  3.07101727447 %
# C= 10 gives an accuracy of:  53.358925144 %
#
# Optimization: stochastic
# C= 0.001 gives an accuracy of:  54.8944337812 %
# C= 0.01 gives an accuracy of:  50.8637236084 %
# C= 0.1 gives an accuracy of:  1.34357005758 %
# C= 1 gives an accuracy of:  0.0 %
# C= 10 gives an accuracy of:  54.8944337812 %
#
# Optimization: bfgs
# C= 0.001 gives an accuracy of:  53.7428023033 %
# C= 0.01 gives an accuracy of:  50.2879078695 %
# C= 0.1 gives an accuracy of:  52.0153550864 %
# C= 1 gives an accuracy of:  54.5105566219 %
# C= 10 gives an accuracy of:  53.5508637236 %

# %%
# %matplotlib inline
from matplotlib import pyplot as plt

plt.figure(figsize=(15, 4))
plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)

for i in range(len(opt)):
    plt.subplot(1, 3, i+1)
    y_pos = np.arange(len(acc_set[i]))
    plt.bar(y_pos, acc_set[i])
    plt.xticks(y_pos, C_val)
    plt.xlabel('Cost')
    plt.ylabel('% Accuracy')
    plt.title(opt[i])
plt.show()

# %%
df_acc_set = pd.DataFrame(np.array(acc_set).reshape(5,3))
df_acc_set.columns = opt
print(df_acc_set)

ax = df_acc_set.boxplot()
ax.set_yscale('linear')
# Out:
#     steepest  stochastic       bfgs
# 0  51.823417    1.151631  51.631478
# 1   3.071017   53.358925  54.894434
# 2  50.863724    1.343570   0.000000
# 3  54.894434   53.742802  50.287908
# 4  52.015355   54.510557  53.550864

# %%
opt = ['stochastic', 'bfgs']
iteration = [100, 1000, 3]
C_val = [0.001, 0.01, 0.1, 1, 10]
reg = ['l1','l2','both']

acc_set = []
for o,i in zip(opt, iteration):
    accuracy = []
    for r in reg:
        acc_r = []
        for j in C_val:
            acc_c = []
            for k in range(15):               
                mlr = MultiClassLogisticRegression(eta=0.01,iterations=i,C=j,optimized_tech=o,norm=r)

                X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)    
                mlr.fit(X_train,y_train)
                yhat = mlr.predict(X_test)
                acc = accuracy_score(y_test,yhat) * 100
                acc_c.append(acc)
            acc_r.append(acc_c)
        accuracy.append(acc_r)
    acc_set.append(accuracy)
    
plt.figure(figsize=(15, 10))
plt.subplots_adjust(bottom=0, left=.01, right=.99, top=.90, hspace=.35)

i = 0
k = 0
for df_acc_r in acc_set:
    j = 0
    for df_acc in df_acc_r:
        plt.subplot(2, 3, i + 1)

        df_acc = pd.DataFrame(np.array(df_acc).reshape(15,5))
        df_acc.columns = C_val

        ax = df_acc.boxplot()
        ax.set_yscale('linear')

        plt.title(opt[k].capitalize() + ' with ' + reg[j].capitalize()  )
        plt.xlabel('Cost')
        plt.ylabel('% Accuracy')

        i += 1
        j += 1
    k += 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-208-38f5eaf32e39> in <module>()
#      35
#      36         df_acc = pd.DataFrame(np.array(df_acc).reshape(5,15))
# ---> 37         df_acc.columns = C_val
#      38
#      39         ax = df_acc.boxplot()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __setattr__(self, name, value)
#    3625         try:
#    3626             object.__getattribute__(self, name)
# -> 3627             return object.__setattr__(self, name, value)
#    3628         except AttributeError:
#    3629             pass
#
# pandas/_libs/properties.pyx in pandas._libs.properties.AxisProperty.__set__()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in _set_axis(self, axis, labels)
#     557
#     558     def _set_axis(self, axis, labels):
# --> 559         self._data.set_axis(axis, labels)
#     560         self._clear_item_cache()
#     561
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\internals.py in set_axis(self, axis, new_labels)
#    3072             raise ValueError('Length mismatch: Expected axis has %d elements, '
#    3073                              'new values have %d elements' %
# -> 3074                              (old_len, new_len))
#    3075
#    3076         self.axes[axis] = new_labels
#
# ValueError: Length mismatch: Expected axis has 15 elements, new values have 5 elements

# %%
# %%time
from sklearn.linear_model import LogisticRegression

# solver : {'newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'}

lg = LogisticRegression(solver='lbfgs')

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
lg.fit(X_train, y_train)

yhat = lg.predict(X_test)

print('Accuracy of: ',accuracy_score(y_test,yhat) * 100, '%')
# Out:
# Accuracy of:  55.8541266795 %
# Wall time: 4.7 s

# %%
# %%time
mlr = MultiClassLogisticRegression(eta=0.01,iterations=5,C=0.01,optimized_tech='bfgs',norm='l2')
        
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)    
mlr.fit(X_train,y_train)
yhat = mlr.predict(X_test)
acc = accuracy_score(y_test,yhat) * 100
print('BFGS gives an accuracy of: ', acc, '%')
# Out:
# BFGS gives an accuracy of:  53.7428023033 %
# Wall time: 1.34 s

# %%
#Training time
#Classification performance
lr_technique = ['Scikit-learn', 'Custom classifier']
accuracy = [60.46, acc]
train_time = [3.15, 1.05]

plt.figure(figsize=(8, 6))

y_pos = np.arange(2)
plt.bar(y_pos, accuracy)
plt.xticks(y_pos, lr_technique)
plt.xlabel('Regression techniques')
plt.title('Performance comparison')

plt.bar(y_pos, train_time)
plt.xticks(y_pos, lr_technique)
plt.xlabel('Regression techniques')
plt.title('Performance comparison')

plt.legend(['Accuracy', 'Training time'])

plt.show()

# %%
# Reference: Notes on MSE Gradients for Neural Networks by David Meyer (http://www.1-4-5.net/~dmm/ml/mse.pdf)
class MSELogisticRegression(BinaryLogisticRegression):
    
#     @staticmethod
    def objective_function(self,w,X,y,C):
        g = expit(X @ w.T)
        return np.sum(g[y==1])+np.sum(1-g[y==0])
    
    
#     def _get_gradient(self,X,y):
#         print(self.w_.shape)
#         g = expit(X @ self.w_)
#         ydiff = y-g # get y difference
#         gradient = np.mean(X * ydiff[:,np.newaxis], axis=0)
#         gradient = gradient.reshape(self.w_.shape)
# #         gradient[1:] += -2 * w[1:] * C
#         if self.norm.lower() == 'l1':
#             gradient[1:] += np.abs(self.w_[1:])/self.w_[1:] * C
#         elif self.norm.lower() == 'l2':
#             gradient[1:] += -2 * self.w_[1:] * C
#         elif self.norm.lower() == 'both':
#             gradient[1:] += (np.abs(self.w_[1:])/self.w_[1:] * C) + (-2 * self.w_[1:] * C)
#         return -gradient
    
    
#     def _get_gradient(self,X,y):
#         print(self.w_.shape)
#         idx = int(np.random.rand()*len(y)) # grab random instance
#         ydiff = y[idx]-self.predict_proba(X[idx],add_bias=False) # get y difference (now scalar)
#         gradient = X[idx] * ydiff[:,np.newaxis] # make ydiff a column vector and multiply through
        
#         gradient = gradient.reshape(self.w_.shape)
        
#         if self.norm.lower() == 'l1':
#             gradient[1:] += np.abs(self.w_[1:])/self.w_[1:] * self.C
#         elif self.norm.lower() == 'l2':
#             gradient[1:] += -2 * self.w_[1:] * self.C
#         elif self.norm.lower() == 'both':
#             gradient[1:] += (np.abs(self.w_[1:])/self.w_[1:] * self.C) + (-2 * self.w_[1:] * self.C)
#         return gradient


    def _get_gradient(self,X,y):
#         X = self._add_bias(X) # add bias term
        num_samples, num_features = X.shape
        self.w_ = self.w_.reshape((num_features,))
        
        print(self.w_.shape)
        g = expit(X @ self.w_.T)
        ydiff = y-g # get y difference
        print(g.shape)
        gradient = np.mean(X * ydiff[:,np.newaxis] * self.objective_function(self.w_,X, y, self.C), axis=0) * -2
        gradient = gradient.reshape(self.w_.shape)
#         gradient[1:] += -2 * w[1:] * C
        if self.norm.lower() == 'l1':
            gradient[1:] += np.abs(self.w_[1:])/self.w_[1:] * self.C
        elif self.norm.lower() == 'l2':
            gradient[1:] += -2 * self.w_[1:] * self.C
        elif self.norm.lower() == 'both':
            gradient[1:] += (np.abs(self.w_[1:])/self.w_[1:] * self.C) + (-2 * self.w_[1:] * self.C)
    
        return -gradient

# %%
# %%time
mlr = MultiClassLogisticRegression(eta=0.1,iterations=1,C=0.01,optimized_tech='mse',norm='l2')
        
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)    
mlr.fit(X_train,y_train)
yhat = mlr.predict(X_test)
acc = accuracy_score(y_test,yhat) * 100
print('accuracy of: %.2f' %acc, '%')
# Out:
# (12,)
# (2082,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <timed exec> in <module>()
#
# <ipython-input-28-77aafcecdc4c> in fit(self, X, y)
#      36             elif(self.optimized_tech.lower() == 'mse'):
#      37                 blr = MSELogisticRegression(self.eta,self.iters,self.C,self.norm)
# ---> 38             blr.fit(X,y_binary)
#      39
#      40             # print(accuracy_score(y_binary,blr.predict(X)))
#
# <ipython-input-24-726bf72c4111> in fit(self, X, y)
#      52         # for as many as the max iterations
#      53         for _ in range(self.iters):
# ---> 54             gradient = self._get_gradient(Xb,y)
#      55             self.w_ += gradient*self.eta # multiply by learning rate
#
# <ipython-input-277-d4ffe259024d> in _get_gradient(self, X, y)
#      56             gradient[1:] += np.abs(self.w_[1:])/self.w_[1:] * self.C
#      57         elif self.norm.lower() == 'l2':
# ---> 58             gradient[1:] += -2 * self.w_[1:] * C
#      59         elif self.norm.lower() == 'both':
#      60             gradient[1:] += (np.abs(self.w_[1:])/self.w_[1:] * self.C) + (-2 * self.w_[1:] * self.C)
#
# NameError: name 'C' is not defined

# %%
# %%time
from sklearn import ensemble
from sklearn.metrics import mean_squared_error

params = {'n_estimators': 500, 'max_depth': 4, 'min_samples_split': 2,
          'learning_rate': 0.01, 'loss': 'ls'}
clf = ensemble.GradientBoostingRegressor(**params)

clf.fit(X_train, y_train)
mse = mean_squared_error(y_test, clf.predict(X_test))
print("MSE: %.4f" % mse)
# Out:
# MSE: 60.9488
# Wall time: 1.99 s
